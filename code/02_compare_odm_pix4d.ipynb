# %%
import glob
import json
import os

import matplotlib.pyplot as plt
import pandas
import yaml

import seabeepy as sb
from seabeepy.config import SETTINGS

plt.style.use("ggplot")

# %% [markdown]
# # Explore ODM results
#
# This notebook compares metrics from the ODM parameter search to output from a reference Pix4D dataset.

# %%
# Add code to get summary metric from the ODM log files and create plots
